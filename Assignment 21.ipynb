# %%
1. Add the current date to the text file today.txt as a string.

# %%
import datetime
current_date_and_time = datetime.datetime.now()
current_date_and_time_string = (current_date_and_time)
extension = ".txt"

file_name =  'today' + extension
file = open(file_name, 'w')
file.write(datetime.datetime.now().ctime())
file.close()

# %%
2. Read the text file today.txt into the string today_string

# %%
with open ("today.txt", "r") as myfile:
    today_string=myfile.readlines()
str1=" "
today_string=str1.join(today_string)
today_string
# Out:
# 'Tue Jul  6 13:23:24 2021'

# %%
3. Parse the date from today_string.

# %%
#from datetime import datetime
#date_time_obj = datetime.strptime(today_string, 'str str int %d/%m/%y %H:%M:%S')

# %%
4. List the files in your current directory

# %%
import os
for subdir, dirs, files in os.walk('./'):
    for file in files:
        print (file)
# Out:
# 10 June 2021.txt
# 2021-06-10.txt
# advance assignment 1.ipynb
# advance assignment 2.ipynb
# advance assignment 3.ipynb
# advance assignment 4.ipynb
# advance assignment 5.ipynb
# Assignment 10.ipynb
# Assignment 11.ipynb
# Assignment 12.ipynb
# Assignment 13.ipynb
# Assignment 14.ipynb
# Assignment 15.ipynb
# Assignment 16.ipynb
# Assignment 17.ipynb
# Assignment 18.ipynb
# Assignment 19.ipynb
# Assignment 2.ipynb
# Assignment 20.ipynb
# Assignment 21.ipynb
# Assignment 22.ipynb
# Assignment 23.ipynb
# Assignment 24.ipynb
# Assignment 25.ipynb
# Assignment 3.ipynb
# Assignment 4.ipynb
# Assignment 5.ipynb
# Assignment 6.ipynb
# Assignment 7.ipynb
# Assignment 8.ipynb
# Assignment 9.ipynb
# Assingment 1.ipynb
# book
# books.csv
# drawing.png
# encryptedbill.pdf
# example.db
# images.jpg
# pyvenv.cfg
# test
# test.time
# today.txt
# zoo.py
# advance assignment 1-checkpoint.ipynb
# advance assignment 2-checkpoint.ipynb
# advance assignment 3-checkpoint.ipynb
# ...

# %%
5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os
path = "C:\\Users\\jai balaji"
dir_list = os.listdir(path)
print("Files and directories in '", path, "' :")
print(dir_list)
# Out:
# Files and directories in ' C:\Users\jai balaji ' :
# ...

# %%
6. Use multiprocessing to create three separate processes. Make each one wait a random number of
seconds between one and five, print the current time, and then exit.

# %%
7. Create a date object of your day of birth.

# %%
from datetime import datetime
bdate = datetime.datetime(int(year), int(month), int(day))

# %%
8. What day of the week was your day of birth?

# %%
import datetime
import calendar
 
def findDay(date):
    born = datetime.datetime.strptime(date, '%d %m %Y').weekday()
    return (calendar.day_name[born])
date = '08 12 2000'
print(findDay(date))
# Out:
# Friday

# %%
9. When will you be (or when were you) 10,000 days old?
